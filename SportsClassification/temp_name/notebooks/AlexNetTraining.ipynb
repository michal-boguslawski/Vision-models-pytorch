# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("gpiosenka/sports-classification")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/sports-classification

# %%
import os
train_dir = path + "/train"
test_dir = path + "/test"

# %%
from model import AlexNet
from model_train_wrapper import ModelTrainWrapper

# %%
training_class = ModelTrainWrapper(model=AlexNet)

# %%
training_class.train(data_path=train_dir, batch_size=16, epochs=20, test_data_path=test_dir)
# Out:
# ...
# Epoch: 19, train set accuracy 0.9812 test set accuracy 0.6125
# Train sample
# Test sample
# Loss plot
